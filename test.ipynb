# %%
# import pandas as pd

# # Load the CSV file to inspect the structure
# csv_file_path = 'FinalProductsList.csv'
# csv_data = pd.read_csv(csv_file_path)

# # Display the first few rows and column names to understand the structure
# csv_data.head(), csv_data.columns
# Out:
# (  Product Number                                       Product Name  \
#  0     Product 01      Customized Wrist Watch with Photo|Logo & Name
#  1     Product 02  Black and Brown stylish Rubber|Silicon Strap W...
#  2     Product 03  Sports Digtal Fashion Watch Women Men Square L...
#  3     Product 04  Men Quartz Watch for Waterproof Vacuum Plating...
#  4     Product 05  Samsung Galaxy A04 3GB - 32GB OFFICIAL PTA APP...
#
#                                     Product Category Brand Name  \
#  0  Watches Sunglasses Jewellery/Watches/Men/Fashion   No Brand
#  1  Watches Sunglasses Jewellery/Watches/Men/Fashion   No Brand
#  2   Watches Sunglasses Jewellery/Watches/Men/Sports   No Brand
#  3  Watches Sunglasses Jewellery/Watches/Men/Fashion   No Brand
#  4                         Mobiles & Tablets/Mobiles    Samsung
#
#               Seller Name                                      Price Details  \
#  0  Personalized Memories             Original: Rs. 999, Discounted: Rs. 585
# ...

# %%
# # Parse price details to extract the discounted price for comparisons
# import re

# def parse_price_details(price_details):
#     """ Extract the lowest discounted price from the price details string. """
#     prices = re.findall(r"Discounted: Rs\. (\d+)", price_details)
#     prices = [int(price) for price in prices]
#     return min(prices) if prices else None

# # Apply the function to extract the minimum discounted prices
# csv_data['Discounted Price'] = csv_data['Price Details'].apply(parse_price_details)

# # Convert percentage ratings to integer for comparison
# csv_data['Positive Seller Ratings'] = csv_data['Positive Seller Ratings'].str.rstrip('%').astype(int)

# # Convert ship on time percentage to integer for comparison
# csv_data['Ship on Time'] = csv_data['Ship on Time'].str.rstrip('%').astype(int)

# # Show the updated DataFrame with new columns for easier processing
# csv_data[['Product Name', 'Brand Name', 'Seller Name', 'Discounted Price', 'Positive Seller Ratings', 'Ship on Time']].head()
# Out:
#                                         Product Name Brand Name  \
# 0      Customized Wrist Watch with Photo|Logo & Name   No Brand
# 1  Black and Brown stylish Rubber|Silicon Strap W...   No Brand
# 2  Sports Digtal Fashion Watch Women Men Square L...   No Brand
# 3  Men Quartz Watch for Waterproof Vacuum Plating...   No Brand
# 4  Samsung Galaxy A04 3GB - 32GB OFFICIAL PTA APP...    Samsung
#
#              Seller Name  Discounted Price  Positive Seller Ratings  \
# 0  Personalized Memories               585                       88
# 1   Modern watch company               450                       79
# 2   Modern watch company               199                       79
# 3             D&K Online              1768                       82
# 4       Samsung Official             18999                       84
#
#    Ship on Time
# 0           100
# 1            97
# 2            97
# 3           100
# 4            65

# %%
# # Define the filters based on the limitations
# limitations = [
#     {'price_exact': 500},  # Rs. 500
#     {'price_range': (1000, 2000)},  # between Rs. 1000 and Rs. 2000
#     {'seller_name': 'Samsung'},  # sold by Samsung
#     {'seller_name': 'New-Gen'},  # sold by New-Gen
#     {'top_rated_sellers': 90},  # 90% or more positive ratings
#     {'ship_on_time': 100},  # 100%
#     {'price_range': (1500, 2500), 'top_rated_sellers': 90},  # between Rs. 1500 and Rs. 2500, top-rated
#     {'price_exact': 5000},  # Rs. 5000
#     {'price_exact': 2000}  # Rs. 2000
# ]

# def filter_products(data, limitation):
#     """ Filter products based on the specific limitation. """
#     filtered = data
#     if 'price_exact' in limitation:
#         filtered = filtered[filtered['Discounted Price'] == limitation['price_exact']]
#     if 'price_range' in limitation:
#         filtered = filtered[(filtered['Discounted Price'] >= limitation['price_range'][0]) &
#                             (filtered['Discounted Price'] <= limitation['price_range'][1])]
#     if 'seller_name' in limitation:
#         filtered = filtered[filtered['Seller Name'] == limitation['seller_name']]
#     if 'top_rated_sellers' in limitation:
#         filtered = filtered[filtered['Positive Seller Ratings'] >= limitation['top_rated_sellers']]
#     if 'ship_on_time' in limitation:
#         filtered = filtered[filtered['Ship on Time'] == limitation['ship_on_time']]
    
#     return filtered[['Product Name', 'Brand Name', 'Seller Name', 'Discounted Price', 'Positive Seller Ratings', 'Ship on Time']]

# # # Apply filters and collect results
# filtered_results = [filter_products(csv_data, lim) for lim in limitations]
# # filtered_results[1]

# # # # print filtered_results to see the results
# # # for i, result in enumerate(filtered_results):
# # #     print(f"Results for limitation {i + 1}:")
# # #     print(result)
# # #     print()

# %%
# def apply_filters(data, limitations):
#     """ Apply the provided limitations as filters on the DataFrame.

#     Args:
#     data (DataFrame): The product data.
#     limitations (list): A list of dictionaries specifying filtering criteria.

#     Returns:
#     list: A list of DataFrames, each containing the filtered results according to each limitation.
#     """

#     def filter_by_price_exact(data, price):
#         """ Filter data where the discounted price is exactly equal to the specified price. """
#         return data[data['Discounted Price'] == price]

#     def filter_by_price_range(data, low, high):
#         """ Filter data where the discounted price falls within the specified range. """
#         return data[(data['Discounted Price'] >= low) & (data['Discounted Price'] <= high)]

#     def filter_by_seller(data, seller):
#         """ Filter data where the seller name matches the specified seller. """
#         return data[data['Seller Name'].str.contains(seller, case=False, na=False)]

#     def filter_by_rating(data, rating):
#         """ Filter data where the positive seller ratings are greater than or equal to the specified rating. """
#         return data[data['Positive Seller Ratings'] >= rating]

#     def filter_by_ship_time(data, time):
#         """ Filter data where the ship on time rate is exactly the specified rate. """
#         return data[data['Ship on Time'] == time]

#     results = []
#     for lim in limitations:
#         filtered_data = data
#         if 'price_exact' in lim:
#             filtered_data = filter_by_price_exact(filtered_data, lim['price_exact'])
#         if 'price_range' in lim:
#             filtered_data = filter_by_price_range(filtered_data, *lim['price_range'])
#         if 'seller_name' in lim:
#             filtered_data = filter_by_seller(filtered_data, lim['seller_name'])
#         if 'top_rated_sellers' in lim:
#             filtered_data = filter_by_rating(filtered_data, lim['top_rated_sellers'])
#         if 'ship_on_time' in lim:
#             filtered_data = filter_by_ship_time(filtered_data, lim['ship_on_time'])

#         results.append(filtered_data)

#     return results

# # Test the apply_filters function with the limitations defined previously
# results_algorithm = apply_filters(csv_data, limitations)

# # Display results from the algorithm for each limitation
# results_algorithm
# Out:
# [Empty DataFrame
#  Columns: [Product Number, Product Name, Product Category, Brand Name, Seller Name, Price Details, Positive Seller Ratings, Ship on Time, Return Policy, Discounted Price]
#  Index: [],
#     Product Number                                       Product Name  \
#  3      Product 04  Men Quartz Watch for Waterproof Vacuum Plating...
#  9      Product 10  2022 trend full-automatic quartz movement men'...
#  16     Product 17  Qiunery YESURPRISE Unisex Antique Case Vintage...
#
#                                      Product Category Brand Name  \
#  3   Watches Sunglasses Jewellery/Watches/Men/Fashion   No Brand
#  9   Watches Sunglasses Jewellery/Watches/Men/Fashion   No Brand
#  16  Watches Sunglasses Jewellery/Watches/Men/Fashion   No Brand
#
#             Seller Name                                      Price Details  \
#  3           D&K Online  Original: Rs. 3999, Discounted: Rs. 1768 | Ori...
# ...

# %%
import pandas as pd
import re

def load_data(filepath):
    """Load the product data from a CSV file and preprocess it."""
    data = pd.read_csv(filepath)
    data['Discounted Price'] = data['Price Details'].apply(
        lambda x: min(map(int, re.findall(r'Discounted: Rs\. (\d+)', x)))
    )
    data['Positive Seller Ratings'] = data['Positive Seller Ratings'].str.rstrip('%').astype(int)
    data['Ship on Time'] = data['Ship on Time'].str.rstrip('%').astype(int)
    return data

def parse_limitation(limitation):
    """Parse the limitation string into a structured dictionary."""
    if 'between Rs.' in limitation:
        low, high = map(int, re.findall(r'\d+', limitation))
        return {'price_range': (low, high)}
    elif 'Rs.' in limitation:
        price = int(re.findall(r'\d+', limitation)[0])
        return {'price_exact': price}
    elif 'sold by' in limitation:
        seller = limitation.split('sold by ')[1].strip()
        return {'seller_name': seller}
    elif 'top-rated sellers' in limitation:
        return {'top_rated_sellers': 90}
    elif '%' in limitation:
        rating = int(re.findall(r'\d+', limitation)[0])
        return {'top_rated_sellers': rating}
    elif 'ship on time' in limitation:
        return {'ship_on_time': 100}
    else:
        return None  # Handle unrecognized input

def filter_products(data, limitation_dict):
    """Apply filters to the data based on parsed limitations."""
    if limitation_dict is None:
        return []
    key, value = next(iter(limitation_dict.items()))
    if key == 'price_exact':
        filtered_data = data[data['Discounted Price'] == value]
    elif key == 'price_range':
        filtered_data = data[(data['Discounted Price'] >= value[0]) & (data['Discounted Price'] <= value[1])]
    elif key == 'seller_name':
        filtered_data = data[data['Seller Name'].str.contains(value, case=False, na=False)]
    elif key == 'top_rated_sellers':
        filtered_data = data[data['Positive Seller Ratings'] >= value]
    elif key == 'ship_on_time':
        filtered_data = data[data['Ship on Time'] == value]
    return filtered_data['Product Number'].tolist()

# Load data
data = load_data('FinalProductsList.csv')

# Example limitation
limitation = "'90%', 'more than 90% positive ratings'"

# Parse and filter products based on the limitation
parsed_limitation = parse_limitation(limitation)
matching_product_numbers = filter_products(data, parsed_limitation)

# Output the product numbers that match the limitation
print("Matching Product Numbers:", matching_product_numbers)
# Out:
# Matching Product Numbers: ['Product 06', 'Product 08', 'Product 12', 'Product 13', 'Product 16', 'Product 18']
